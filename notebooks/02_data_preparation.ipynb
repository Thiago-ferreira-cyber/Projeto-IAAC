# %% [markdown]
# # Data Preparation
#
# Fase de limpeza e preparação dos dados, usando as funções de `data_preparation.py`.

# %%
import data_preparation as dp

# %% [markdown]
# ## 1. Carregar o dataset

# %%
DATA_PATH = "Malware_and_benign_recognition.csv"
df = dp.load_data(DATA_PATH)

# %% [markdown]
# ## 2. Valores nulos e duplicados

# %%
dp.check_missing_duplicates(df)

# %% [markdown]
# ## 3. Limpeza (tipos de dados + remoção de identificadores)

# %%
df_clean = dp.clean_data(df, id_column="File")
df_clean.dtypes

# %% [markdown]
# ## 4. Separar features (X) e target (y)

# %%
TARGET = "Malicious"
X, y = dp.split_features_target(df_clean, TARGET)

# %% [markdown]
# ## 5. Dividir em treino e teste

# %%
X_train, X_test, y_train, y_test = dp.split_train_test(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# ## Alternativa: correr tudo de uma vez

# %%
# X_train, X_test, y_train, y_test = dp.run_data_preparation(DATA_PATH, target=TARGET)

# %% [markdown]
# ## Dados prontos para a fase de Modeling
#
# `X_train`, `X_test`, `y_train`, `y_test` ficam disponíveis para o notebook/script seguinte.
